# %% [markdown]
# # Installation of required packages

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/My Drive/GeSumGenEval/src
# Out:
# /content/drive/.shortcut-targets-by-id/1PcWXs_So5sTaP0wBAR77_ORSfd4aFtHq/GeSumGenEval/src

# %%
# !pip install -r ../requirements.txt
# Out:
# Processing /content/drive/.shortcut-targets-by-id/1PcWXs_So5sTaP0wBAR77_ORSfd4aFtHq/GeSumGenEval/emnlp19-moverscore
# Requirement already satisfied: cytoolz==0.11.0 in /usr/local/lib/python3.7/dist-packages (from -r ../requirements.txt (line 1)) (0.11.0)
# Requirement already satisfied: datasets==1.7.0 in /usr/local/lib/python3.7/dist-packages (from -r ../requirements.txt (line 2)) (1.7.0)
# Requirement already satisfied: dill==0.3.3 in /usr/local/lib/python3.7/dist-packages (from -r ../requirements.txt (line 3)) (0.3.3)
# Requirement already satisfied: FastNLP==0.6.0 in /usr/local/lib/python3.7/dist-packages (from -r ../requirements.txt (line 5)) (0.6.0)
# Requirement already satisfied: multiprocess==0.70.11.1 in /usr/local/lib/python3.7/dist-packages (from -r ../requirements.txt (line 6)) (0.70.11.1)
# Requirement already satisfied: numpy==1.20.3 in /usr/local/lib/python3.7/dist-packages (from -r ../requirements.txt (line 7)) (1.20.3)
# Requirement already satisfied: rouge==1.0.0 in /usr/local/lib/python3.7/dist-packages (from -r ../requirements.txt (line 8)) (1.0.0)
# Requirement already satisfied: SoMaJo==2.1.3 in /usr/local/lib/python3.7/dist-packages (from -r ../requirements.txt (line 9)) (2.1.3)
# Requirement already satisfied: summa==1.2.0 in /usr/local/lib/python3.7/dist-packages (from -r ../requirements.txt (line 10)) (1.2.0)
# Requirement already satisfied: summ-eval==0.30 in /usr/local/lib/python3.7/dist-packages (from -r ../requirements.txt (line 11)) (0.30)
# Requirement already satisfied: tensorboardX==2.2 in /usr/local/lib/python3.7/dist-packages (from -r ../requirements.txt (line 12)) (2.2)
# Requirement already satisfied: plotly==4.14.3 in /usr/local/lib/python3.7/dist-packages (from -r ../requirements.txt (line 13)) (4.14.3)
# Requirement already satisfied: typing in /usr/local/lib/python3.7/dist-packages (from moverscore==0.96->-r ../requirements.txt (line 4)) (3.7.4.3)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.7/dist-packages (from moverscore==0.96->-r ../requirements.txt (line 4)) (2.3.0)
# Requirement already satisfied: toolz>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from cytoolz==0.11.0->-r ../requirements.txt (line 1)) (0.11.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from datasets==1.7.0->-r ../requirements.txt (line 2)) (4.5.0)
# Requirement already satisfied: pyarrow<4.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets==1.7.0->-r ../requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets==1.7.0->-r ../requirements.txt (line 2)) (2.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets==1.7.0->-r ../requirements.txt (line 2)) (20.9)
# Requirement already satisfied: huggingface-hub<0.1.0 in /usr/local/lib/python3.7/dist-packages (from datasets==1.7.0->-r ../requirements.txt (line 2)) (0.0.13)
# Requirement already satisfied: tqdm<4.50.0,>=4.27 in /usr/local/lib/python3.7/dist-packages (from datasets==1.7.0->-r ../requirements.txt (line 2)) (4.41.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets==1.7.0->-r ../requirements.txt (line 2)) (1.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.7/dist-packages (from datasets==1.7.0->-r ../requirements.txt (line 2)) (2021.6.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from datasets==1.7.0->-r ../requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: spacy in /usr/local/lib/python3.7/dist-packages (from FastNLP==0.6.0->-r ../requirements.txt (line 5)) (2.2.4)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from FastNLP==0.6.0->-r ../requirements.txt (line 5)) (1.9.0+cu102)
# Requirement already satisfied: prettytable>=0.7.2 in /usr/local/lib/python3.7/dist-packages (from FastNLP==0.6.0->-r ../requirements.txt (line 5)) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from FastNLP==0.6.0->-r ../requirements.txt (line 5)) (2019.12.20)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from rouge==1.0.0->-r ../requirements.txt (line 8)) (1.15.0)
# Requirement already satisfied: scipy>=0.19 in /usr/local/lib/python3.7/dist-packages (from summa==1.2.0->-r ../requirements.txt (line 10)) (1.4.1)
# Requirement already satisfied: wmd in /usr/local/lib/python3.7/dist-packages (from summ-eval==0.30->-r ../requirements.txt (line 11)) (1.3.2)
# Requirement already satisfied: bert-score in /usr/local/lib/python3.7/dist-packages (from summ-eval==0.30->-r ../requirements.txt (line 11)) (0.3.9)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from summ-eval==0.30->-r ../requirements.txt (line 11)) (5.4.8)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from summ-eval==0.30->-r ../requirements.txt (line 11)) (7.1.2)
# Requirement already satisfied: blanc in /usr/local/lib/python3.7/dist-packages (from summ-eval==0.30->-r ../requirements.txt (line 11)) (0.2.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from summ-eval==0.30->-r ../requirements.txt (line 11)) (2.5.1)
# Requirement already satisfied: pyemd==0.5.1 in /usr/local/lib/python3.7/dist-packages (from summ-eval==0.30->-r ../requirements.txt (line 11)) (0.5.1)
# Requirement already satisfied: pytorch-pretrained-bert in /usr/local/lib/python3.7/dist-packages (from summ-eval==0.30->-r ../requirements.txt (line 11)) (0.6.2)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from summ-eval==0.30->-r ../requirements.txt (line 11)) (0.0.45)
# Requirement already satisfied: sacrebleu in /usr/local/lib/python3.7/dist-packages (from summ-eval==0.30->-r ../requirements.txt (line 11)) (1.5.1)
# Requirement already satisfied: pyrouge in /usr/local/lib/python3.7/dist-packages (from summ-eval==0.30->-r ../requirements.txt (line 11)) (0.1.3)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from summ-eval==0.30->-r ../requirements.txt (line 11)) (0.0)
# Requirement already satisfied: transformers>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from summ-eval==0.30->-r ../requirements.txt (line 11)) (4.8.2)
# Requirement already satisfied: stanza in /usr/local/lib/python3.7/dist-packages (from summ-eval==0.30->-r ../requirements.txt (line 11)) (1.2.1)
# Requirement already satisfied: gin-config in /usr/local/lib/python3.7/dist-packages (from summ-eval==0.30->-r ../requirements.txt (line 11)) (0.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from summ-eval==0.30->-r ../requirements.txt (line 11)) (3.2.5)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorboardX==2.2->-r ../requirements.txt (line 12)) (3.12.4)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.7/dist-packages (from plotly==4.14.3->-r ../requirements.txt (line 13)) (1.3.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->datasets==1.7.0->-r ../requirements.txt (line 2)) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->datasets==1.7.0->-r ../requirements.txt (line 2)) (3.7.4.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets==1.7.0->-r ../requirements.txt (line 2)) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets==1.7.0->-r ../requirements.txt (line 2)) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets==1.7.0->-r ../requirements.txt (line 2)) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets==1.7.0->-r ../requirements.txt (line 2)) (1.24.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets==1.7.0->-r ../requirements.txt (line 2)) (2.4.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<0.1.0->datasets==1.7.0->-r ../requirements.txt (line 2)) (3.0.12)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets==1.7.0->-r ../requirements.txt (line 2)) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets==1.7.0->-r ../requirements.txt (line 2)) (2018.9)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy->FastNLP==0.6.0->-r ../requirements.txt (line 5)) (57.0.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy->FastNLP==0.6.0->-r ../requirements.txt (line 5)) (3.0.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy->FastNLP==0.6.0->-r ../requirements.txt (line 5)) (1.0.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy->FastNLP==0.6.0->-r ../requirements.txt (line 5)) (0.8.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy->FastNLP==0.6.0->-r ../requirements.txt (line 5)) (1.0.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy->FastNLP==0.6.0->-r ../requirements.txt (line 5)) (1.1.3)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy->FastNLP==0.6.0->-r ../requirements.txt (line 5)) (7.4.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy->FastNLP==0.6.0->-r ../requirements.txt (line 5)) (1.0.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy->FastNLP==0.6.0->-r ../requirements.txt (line 5)) (2.0.5)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy->FastNLP==0.6.0->-r ../requirements.txt (line 5)) (0.4.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prettytable>=0.7.2->FastNLP==0.6.0->-r ../requirements.txt (line 5)) (0.2.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from bert-score->summ-eval==0.30->-r ../requirements.txt (line 11)) (3.2.2)
# Requirement already satisfied: decorator<5,>=4.3 in /usr/local/lib/python3.7/dist-packages (from networkx->summ-eval==0.30->-r ../requirements.txt (line 11)) (4.4.2)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.7/dist-packages (from pytorch-pretrained-bert->summ-eval==0.30->-r ../requirements.txt (line 11)) (1.17.102)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->summ-eval==0.30->-r ../requirements.txt (line 11)) (1.0.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn->summ-eval==0.30->-r ../requirements.txt (line 11)) (0.22.2.post1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from transformers>=2.2.0->summ-eval==0.30->-r ../requirements.txt (line 11)) (3.13)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers>=2.2.0->summ-eval==0.30->-r ../requirements.txt (line 11)) (0.10.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->bert-score->summ-eval==0.30->-r ../requirements.txt (line 11)) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->bert-score->summ-eval==0.30->-r ../requirements.txt (line 11)) (1.3.1)
# Requirement already satisfied: s3transfer<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from boto3->pytorch-pretrained-bert->summ-eval==0.30->-r ../requirements.txt (line 11)) (0.4.2)
# Requirement already satisfied: botocore<1.21.0,>=1.20.102 in /usr/local/lib/python3.7/dist-packages (from boto3->pytorch-pretrained-bert->summ-eval==0.30->-r ../requirements.txt (line 11)) (1.20.102)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from boto3->pytorch-pretrained-bert->summ-eval==0.30->-r ../requirements.txt (line 11)) (0.10.0)
# Building wheels for collected packages: moverscore
#   Building wheel for moverscore (setup.py) ... done
#   Created wheel for moverscore: filename=moverscore-0.96-cp37-none-any.whl size=8826 sha256=cddee2d43af4949c50f5785385934be29b2588bf33fa32fb022a3f1aeb598b06
#   Stored in directory: /root/.cache/pip/wheels/79/75/ea/13343d846ad4741f6c07088b71b7c8038a182240999ca30895
# Successfully built moverscore
# Installing collected packages: moverscore
#   Found existing installation: moverscore 0.96
#     Uninstalling moverscore-0.96:
#       Successfully uninstalled moverscore-0.96
# Successfully installed moverscore-0.96

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Wed Jun 30 13:36:37 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # MLSUM

# %%
# !python train.py -mode oracle -bert_data_path ../bert_data/mlsum -model_path ../models/mlsum -log_file ../logs/mlsum -result_path ../results/mlsum -visible_gpus 0
#!python train.py -mode lead -bert_data_path ../bert_data/mlsum -model_path ../models/mlsum -log_file ../logs/mlsum -result_path ../results/mlsum #-visible_gpus 0
# Out:
# [2021-06-30 13:37:17,993 INFO] Loading test dataset from ../bert_data/mlsum/test.0.bert.pt, number of examples: 2000
# gpu_rank 0
# [2021-06-30 13:37:30,179 INFO] Loading test dataset from ../bert_data/mlsum/test.1.bert.pt, number of examples: 2000
# [2021-06-30 13:37:33,011 INFO] Loading test dataset from ../bert_data/mlsum/test.2.bert.pt, number of examples: 2000
# [2021-06-30 13:37:35,828 INFO] Loading test dataset from ../bert_data/mlsum/test.3.bert.pt, number of examples: 2000
# [2021-06-30 13:37:38,664 INFO] Loading test dataset from ../bert_data/mlsum/test.4.bert.pt, number of examples: 2000
# [2021-06-30 13:37:41,276 INFO] Loading test dataset from ../bert_data/mlsum/test.5.bert.pt, number of examples: 701
# [2021-06-30 13:37:42,299 INFO] Validation xent: 0 at step 0

# %%
#!python preprocess.py -mode format_to_bert -raw_path ../json_data/mlsum -save_path ../bert_data/mlsum -oracle_mode greedy -n_cpus 4 -log_file ../logs/preprocess.log

# %%
# !python train.py -mode train -encoder transformer -dropout 0.1 -bert_data_path ../bert_data/mlsum -model_path ../models/mlsum -lr 2e-3 -visible_gpus 0 -gpu_ranks 0 -world_size 1 \
-report_every 50 -save_checkpoint_steps 1000 -batch_size 3000 -decay_method noam -train_steps 50000 -accum_count 2 -log_file ../logs/mlsum -use_interval true -warmup_steps 10000 \
-ff_size 2048 -inter_layers 2 -heads 8 -train_from ../models/mlsum/model_step_11000.pt

# %%
# !python train.py -mode validate -bert_data_path ../bert_data/mlsum -model_path ../models/mlsum -visible_gpus 0 -gpu_ranks 0 -batch_size 30000 -log_file ../logs/mlsum -result_path ../results/mlsum -test_all -block_trigram true

# %%
# !python train.py -mode test -bert_data_path ../bert_data/mlsum -test_from ../models/mlsum/model_step_45000.pt -log_file ../logs/mlsum -result_path ../results/mlsum -visible_gpus 0
# Out:
# [2021-06-30 13:39:17,614 INFO] Loading checkpoint from ../models/mlsum/model_step_45000.pt
# Namespace(accum_count=1, batch_size=1000, bert_config_path='../bert_config_uncased_base.json', bert_data_path='../bert_data/mlsum', beta1=0.9, beta2=0.999, block_trigram=True, dataset='', decay_method='', dropout=0.1, encoder='transformer', ff_size=2048, gpu_ranks=[0], heads=8, hidden_size=128, inter_layers=2, log_file='../logs/mlsum', lr=1, max_grad_norm=0, mode='test', model_path='models/', optim='adam', param_init=0, param_init_glorot=True, recall_eval=False, report_every=1, report_rouge=False, result_path='../results/mlsum', rnn_size=512, save_checkpoint_steps=5, seed=666, temp_dir='temp', test_all=False, test_from='../models/mlsum/model_step_45000.pt', train_from='', train_steps=1000, use_interval=True, visible_gpus='0', warmup_steps=8000, world_size=1)
# [2021-06-30 13:39:42,117 INFO] Loading test dataset from ../bert_data/mlsum/test.0.bert.pt, number of examples: 2000
# gpu_rank 0
# [2021-06-30 13:39:42,124 INFO] * number of parameters: 120957953
# [2021-06-30 13:40:28,305 INFO] Loading test dataset from ../bert_data/mlsum/test.1.bert.pt, number of examples: 2000
# [2021-06-30 13:41:14,087 INFO] Loading test dataset from ../bert_data/mlsum/test.2.bert.pt, number of examples: 2000
# [2021-06-30 13:42:00,298 INFO] Loading test dataset from ../bert_data/mlsum/test.3.bert.pt, number of examples: 2000
# [2021-06-30 13:42:46,535 INFO] Loading test dataset from ../bert_data/mlsum/test.4.bert.pt, number of examples: 2000
# [2021-06-30 13:43:32,715 INFO] Loading test dataset from ../bert_data/mlsum/test.5.bert.pt, number of examples: 701
# [2021-06-30 13:43:48,939 INFO] Validation xent: 3.65659 at step 45000

# %% [markdown]
# # GeWiki

# %%
# !python train.py -mode oracle -bert_data_path ../bert_data/gewiki -model_path ../models/gewiki -log_file ../logs/gewiki -result_path ../results/gewiki -visible_gpus 0
#!python train.py -mode lead -bert_data_path ../bert_data/gewiki -model_path ../models/gewiki -log_file ../logs/gewiki -result_path ../results/gewiki #-visible_gpus 0
# Out:
# [2021-06-30 13:45:23,239 INFO] Loading test dataset from ../bert_data/gewiki/test.0.bert.pt, number of examples: 2000
# gpu_rank 0
# [2021-06-30 13:45:29,092 INFO] Loading test dataset from ../bert_data/gewiki/test.1.bert.pt, number of examples: 2000
# [2021-06-30 13:45:32,629 INFO] Loading test dataset from ../bert_data/gewiki/test.2.bert.pt, number of examples: 2000
# [2021-06-30 13:45:35,803 INFO] Loading test dataset from ../bert_data/gewiki/test.3.bert.pt, number of examples: 2000
# [2021-06-30 13:45:39,500 INFO] Loading test dataset from ../bert_data/gewiki/test.4.bert.pt, number of examples: 2000
# [2021-06-30 13:45:41,439 INFO] Validation xent: 0 at step 0

# %%
#!python preprocess.py -mode format_to_bert -raw_path ../json_data/gewiki -save_path ../bert_data/gewiki -oracle_mode greedy -n_cpus 4 -log_file ../logs/preprocess.log

# %%
# !python train.py -mode train -encoder transformer -dropout 0.1 -bert_data_path ../bert_data/gewiki -model_path ../models/gewiki  -lr 2e-3 -visible_gpus 0  -gpu_ranks 0 -world_size 1 \
-report_every 50 -save_checkpoint_steps 1000 -batch_size 3000 -decay_method noam -train_steps 50000 -accum_count 2 -log_file ../logs/gewiki -use_interval true -warmup_steps 10000 \
-ff_size 2048 -inter_layers 2 -heads 8 #-train_from ../models/gewiki/model_step_17000.pt

# %%
# !python train.py -mode validate -bert_data_path ../bert_data/gewiki -model_path ../models/gewiki -visible_gpus 0 -gpu_ranks 0 -batch_size 30000 -log_file ../logs/gewiki -result_path ../results/gewiki -test_all -block_trigram true

# %%
# !python train.py -mode test -bert_data_path ../bert_data/gewiki -test_from ../models/gewiki/model_step_40000.pt -log_file ../logs/gewiki -result_path ../results/gewiki -visible_gpus 0
# Out:
# [2021-06-30 13:45:53,290 INFO] Loading checkpoint from ../models/gewiki/model_step_40000.pt
# Namespace(accum_count=1, batch_size=1000, bert_config_path='../bert_config_uncased_base.json', bert_data_path='../bert_data/gewiki', beta1=0.9, beta2=0.999, block_trigram=True, dataset='', decay_method='', dropout=0.1, encoder='transformer', ff_size=2048, gpu_ranks=[0], heads=8, hidden_size=128, inter_layers=2, log_file='../logs/gewiki', lr=1, max_grad_norm=0, mode='test', model_path='models/', optim='adam', param_init=0, param_init_glorot=True, recall_eval=False, report_every=1, report_rouge=False, result_path='../results/gewiki', rnn_size=512, save_checkpoint_steps=5, seed=666, temp_dir='temp', test_all=False, test_from='../models/gewiki/model_step_40000.pt', train_from='', train_steps=1000, use_interval=True, visible_gpus='0', warmup_steps=8000, world_size=1)
# [2021-06-30 13:46:19,862 INFO] Loading test dataset from ../bert_data/gewiki/test.0.bert.pt, number of examples: 2000
# gpu_rank 0
# [2021-06-30 13:46:19,869 INFO] * number of parameters: 120957953
# [2021-06-30 13:47:05,965 INFO] Loading test dataset from ../bert_data/gewiki/test.1.bert.pt, number of examples: 2000
# [2021-06-30 13:47:50,516 INFO] Loading test dataset from ../bert_data/gewiki/test.2.bert.pt, number of examples: 2000
# [2021-06-30 13:48:34,472 INFO] Loading test dataset from ../bert_data/gewiki/test.3.bert.pt, number of examples: 2000
# [2021-06-30 13:49:18,941 INFO] Loading test dataset from ../bert_data/gewiki/test.4.bert.pt, number of examples: 2000
# [2021-06-30 13:50:01,375 INFO] Validation xent: 3.99711 at step 40000
