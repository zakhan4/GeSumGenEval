# %% [markdown]
# # Installation of required packages

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/My Drive/GeSumGenEval/src
# Out:
# /content/drive/.shortcut-targets-by-id/1PcWXs_So5sTaP0wBAR77_ORSfd4aFtHq/GeSumGenEval/src

# %%
# !pip install -r ../requirements.txt
# Out:
# Processing /content/drive/.shortcut-targets-by-id/1PcWXs_So5sTaP0wBAR77_ORSfd4aFtHq/GeSumGenEval/emnlp19-moverscore
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# Requirement already satisfied: cytoolz==0.11.0 in /usr/local/lib/python3.7/dist-packages (from -r ../requirements.txt (line 1)) (0.11.0)
# Requirement already satisfied: datasets==1.7.0 in /usr/local/lib/python3.7/dist-packages (from -r ../requirements.txt (line 2)) (1.7.0)
# Requirement already satisfied: dill==0.3.3 in /usr/local/lib/python3.7/dist-packages (from -r ../requirements.txt (line 3)) (0.3.3)
# Requirement already satisfied: FastNLP==0.6.0 in /usr/local/lib/python3.7/dist-packages (from -r ../requirements.txt (line 5)) (0.6.0)
# Requirement already satisfied: multiprocess==0.70.11.1 in /usr/local/lib/python3.7/dist-packages (from -r ../requirements.txt (line 6)) (0.70.11.1)
# Requirement already satisfied: numpy==1.20.3 in /usr/local/lib/python3.7/dist-packages (from -r ../requirements.txt (line 7)) (1.20.3)
# Requirement already satisfied: rouge==1.0.0 in /usr/local/lib/python3.7/dist-packages (from -r ../requirements.txt (line 8)) (1.0.0)
# Requirement already satisfied: SoMaJo==2.1.3 in /usr/local/lib/python3.7/dist-packages (from -r ../requirements.txt (line 9)) (2.1.3)
# Requirement already satisfied: summa==1.2.0 in /usr/local/lib/python3.7/dist-packages (from -r ../requirements.txt (line 10)) (1.2.0)
# Requirement already satisfied: summ-eval==0.30 in /usr/local/lib/python3.7/dist-packages (from -r ../requirements.txt (line 11)) (0.30)
# Requirement already satisfied: tensorboardX==2.2 in /usr/local/lib/python3.7/dist-packages (from -r ../requirements.txt (line 12)) (2.2)
# Requirement already satisfied: plotly==4.14.3 in /usr/local/lib/python3.7/dist-packages (from -r ../requirements.txt (line 13)) (4.14.3)
# Requirement already satisfied: typing in /usr/local/lib/python3.7/dist-packages (from moverscore==0.96->-r ../requirements.txt (line 4)) (3.7.4.3)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.7/dist-packages (from moverscore==0.96->-r ../requirements.txt (line 4)) (2.4.0)
# Requirement already satisfied: toolz>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from cytoolz==0.11.0->-r ../requirements.txt (line 1)) (0.11.2)
# Requirement already satisfied: pyarrow<4.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets==1.7.0->-r ../requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets==1.7.0->-r ../requirements.txt (line 2)) (21.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets==1.7.0->-r ../requirements.txt (line 2)) (1.3.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.7/dist-packages (from datasets==1.7.0->-r ../requirements.txt (line 2)) (2022.2.0)
# Requirement already satisfied: tqdm<4.50.0,>=4.27 in /usr/local/lib/python3.7/dist-packages (from datasets==1.7.0->-r ../requirements.txt (line 2)) (4.49.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets==1.7.0->-r ../requirements.txt (line 2)) (2.23.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from datasets==1.7.0->-r ../requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets==1.7.0->-r ../requirements.txt (line 2)) (4.11.1)
# Requirement already satisfied: huggingface-hub<0.1.0 in /usr/local/lib/python3.7/dist-packages (from datasets==1.7.0->-r ../requirements.txt (line 2)) (0.0.19)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from FastNLP==0.6.0->-r ../requirements.txt (line 5)) (2019.12.20)
# Requirement already satisfied: prettytable>=0.7.2 in /usr/local/lib/python3.7/dist-packages (from FastNLP==0.6.0->-r ../requirements.txt (line 5)) (3.1.1)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from FastNLP==0.6.0->-r ../requirements.txt (line 5)) (1.10.0+cu111)
# Requirement already satisfied: spacy in /usr/local/lib/python3.7/dist-packages (from FastNLP==0.6.0->-r ../requirements.txt (line 5)) (2.2.4)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from rouge==1.0.0->-r ../requirements.txt (line 8)) (1.15.0)
# Requirement already satisfied: scipy>=0.19 in /usr/local/lib/python3.7/dist-packages (from summa==1.2.0->-r ../requirements.txt (line 10)) (1.4.1)
# Requirement already satisfied: stanza in /usr/local/lib/python3.7/dist-packages (from summ-eval==0.30->-r ../requirements.txt (line 11)) (1.3.0)
# Requirement already satisfied: blanc in /usr/local/lib/python3.7/dist-packages (from summ-eval==0.30->-r ../requirements.txt (line 11)) (0.2.6)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from summ-eval==0.30->-r ../requirements.txt (line 11)) (0.0.47)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from summ-eval==0.30->-r ../requirements.txt (line 11)) (0.0)
# Requirement already satisfied: transformers>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from summ-eval==0.30->-r ../requirements.txt (line 11)) (4.12.2)
# Requirement already satisfied: pytorch-pretrained-bert in /usr/local/lib/python3.7/dist-packages (from summ-eval==0.30->-r ../requirements.txt (line 11)) (0.6.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from summ-eval==0.30->-r ../requirements.txt (line 11)) (3.2.5)
# Requirement already satisfied: sacrebleu in /usr/local/lib/python3.7/dist-packages (from summ-eval==0.30->-r ../requirements.txt (line 11)) (2.0.0)
# Requirement already satisfied: gin-config in /usr/local/lib/python3.7/dist-packages (from summ-eval==0.30->-r ../requirements.txt (line 11)) (0.5.0)
# Requirement already satisfied: pyemd==0.5.1 in /usr/local/lib/python3.7/dist-packages (from summ-eval==0.30->-r ../requirements.txt (line 11)) (0.5.1)
# Requirement already satisfied: wmd in /usr/local/lib/python3.7/dist-packages (from summ-eval==0.30->-r ../requirements.txt (line 11)) (1.3.2)
# Requirement already satisfied: bert-score in /usr/local/lib/python3.7/dist-packages (from summ-eval==0.30->-r ../requirements.txt (line 11)) (0.3.11)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from summ-eval==0.30->-r ../requirements.txt (line 11)) (7.1.2)
# Requirement already satisfied: pyrouge in /usr/local/lib/python3.7/dist-packages (from summ-eval==0.30->-r ../requirements.txt (line 11)) (0.1.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from summ-eval==0.30->-r ../requirements.txt (line 11)) (5.4.8)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from summ-eval==0.30->-r ../requirements.txt (line 11)) (2.6.3)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorboardX==2.2->-r ../requirements.txt (line 12)) (3.17.3)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.7/dist-packages (from plotly==4.14.3->-r ../requirements.txt (line 13)) (1.3.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<0.1.0->datasets==1.7.0->-r ../requirements.txt (line 2)) (3.10.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<0.1.0->datasets==1.7.0->-r ../requirements.txt (line 2)) (3.6.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<0.1.0->datasets==1.7.0->-r ../requirements.txt (line 2)) (6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets==1.7.0->-r ../requirements.txt (line 2)) (3.0.7)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prettytable>=0.7.2->FastNLP==0.6.0->-r ../requirements.txt (line 5)) (0.2.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets==1.7.0->-r ../requirements.txt (line 2)) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets==1.7.0->-r ../requirements.txt (line 2)) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets==1.7.0->-r ../requirements.txt (line 2)) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets==1.7.0->-r ../requirements.txt (line 2)) (3.0.4)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy->FastNLP==0.6.0->-r ../requirements.txt (line 5)) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy->FastNLP==0.6.0->-r ../requirements.txt (line 5)) (1.0.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy->FastNLP==0.6.0->-r ../requirements.txt (line 5)) (2.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy->FastNLP==0.6.0->-r ../requirements.txt (line 5)) (0.9.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy->FastNLP==0.6.0->-r ../requirements.txt (line 5)) (1.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy->FastNLP==0.6.0->-r ../requirements.txt (line 5)) (57.4.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy->FastNLP==0.6.0->-r ../requirements.txt (line 5)) (1.1.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy->FastNLP==0.6.0->-r ../requirements.txt (line 5)) (3.0.6)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy->FastNLP==0.6.0->-r ../requirements.txt (line 5)) (7.4.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy->FastNLP==0.6.0->-r ../requirements.txt (line 5)) (0.4.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets==1.7.0->-r ../requirements.txt (line 2)) (3.7.0)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers>=2.2.0->summ-eval==0.30->-r ../requirements.txt (line 11)) (0.10.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from bert-score->summ-eval==0.30->-r ../requirements.txt (line 11)) (3.2.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets==1.7.0->-r ../requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets==1.7.0->-r ../requirements.txt (line 2)) (2018.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->bert-score->summ-eval==0.30->-r ../requirements.txt (line 11)) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->bert-score->summ-eval==0.30->-r ../requirements.txt (line 11)) (1.3.2)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.7/dist-packages (from pytorch-pretrained-bert->summ-eval==0.30->-r ../requirements.txt (line 11)) (1.21.7)
# Requirement already satisfied: botocore<1.25.0,>=1.24.7 in /usr/local/lib/python3.7/dist-packages (from boto3->pytorch-pretrained-bert->summ-eval==0.30->-r ../requirements.txt (line 11)) (1.24.7)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from boto3->pytorch-pretrained-bert->summ-eval==0.30->-r ../requirements.txt (line 11)) (0.10.0)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from boto3->pytorch-pretrained-bert->summ-eval==0.30->-r ../requirements.txt (line 11)) (0.5.2)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu->summ-eval==0.30->-r ../requirements.txt (line 11)) (0.8.9)
# Requirement already satisfied: colorama in /usr/local/lib/python3.7/dist-packages (from sacrebleu->summ-eval==0.30->-r ../requirements.txt (line 11)) (0.4.4)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->summ-eval==0.30->-r ../requirements.txt (line 11)) (1.1.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn->summ-eval==0.30->-r ../requirements.txt (line 11)) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn->summ-eval==0.30->-r ../requirements.txt (line 11)) (3.1.0)
# Requirement already satisfied: emoji in /usr/local/lib/python3.7/dist-packages (from stanza->summ-eval==0.30->-r ../requirements.txt (line 11)) (1.6.3)
# Building wheels for collected packages: moverscore
#   Building wheel for moverscore (setup.py) ... done
#   Created wheel for moverscore: filename=moverscore-0.96-py3-none-any.whl size=8824 sha256=cb80b67aa8ddaf622cad8ea5fdb23f9031534dd08570ee6513c878425cb01ce7
#   Stored in directory: /root/.cache/pip/wheels/8c/58/59/96a9ad992efa037ee095da5ba29bf1028e93e9db25ecd80ff9
# Successfully built moverscore
# Installing collected packages: moverscore
#   Attempting uninstall: moverscore
#     Found existing installation: moverscore 0.96
#     Uninstalling moverscore-0.96:
#       Successfully uninstalled moverscore-0.96
# Successfully installed moverscore-0.96

# %%
import sys
import nltk

print(sys.executable)

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# /usr/bin/python3
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Fri Feb 25 07:47:32 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   53C    P0    59W / 149W |   1134MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Summarization

# %%
import summarize
from importlib import reload


texts = [
         "Die Fensterspinne (Amaurobius fenestralis) oder Waldfinsterspinne ist eine Spinne innerhalb der Familie der Finsterspinnen (Amaurobiidae). Die paläarktisch verbreitete Art zählt zusammen mit der gattungsverwandten Kellerspinne (Amaurobius ferox) sowie der Ähnlichen Fensterspinne (Amaurobius similis) zu den häufigsten der Familie in Europa. Der Trivialname „Fensterspinne“ rührt von der irrtümlichen Annahme her, dass die Art gerne im Bereich von Fenstern lebt. Dies ist mittlerweile widerlegt und ist mit hoher Wahrscheinlichkeit auf Verwechslungen mit der verwandten Ähnlichen Fensterspinne zurückzuführen, bei der dieses Verhalten vorkommt und die überdies früher nicht als eigene Art von der Fensterspinne unterschieden wurde. Die Fensterspinne selbst bewohnt hingegen bevorzugt Wälder und seltener Keller oder Höhlen. Im englischen Sprachraum wird die Fensterspinne als Window spider oder wie die Ähnliche Fensterspinne als Lace-webbed spider (übersetzt etwa „Spitzenweberspinne“) bezeichnet. Beide englischen Bezeichnungen nehmen Bezug auf das Trichternetz, das wie bei allen Echten Finsterspinnen (Amaurobius) mit cribellater Fangwolle versehen ist. Mit dessen Hilfe erbeutet die nachtaktive Fensterspinne eine Vielzahl von Gliederfüßern und kann auch wehrhafte Vertreter dieses Stammes überwältigen. Das Trichternetz mündet weiter hinten in einer als Aufenthaltsort der Spinne dienenden Wohnröhre, in der ein verpaartes Weibchen später auch seinen Eikokon deponiert. Die geschlüpften Jungtiere verhalten sich wie bei allen Echten Finsterspinnen matriphag, bzw. sie saugen ihre kurz nach dem Schlupf verendende Mutter aus und überwintern gemeinsam in ihrem Netz, ehe sie sich im folgenden Frühjahr trennen und selbstständig heranwachsen."
]

summarize = reload(summarize)
summarize.summarize_with_bertsum(texts)
# Out:
# Sentence splitting, tokenizing and converting to json...
# []
# []
# [('../json_data/temp/test.0.json', <summarize.clsprops object at 0x7fddd0cce5d0>, '../bert_data/temp/test.0.bert.pt')]
# [2022-02-25 07:54:33,296 INFO] Ignore ../bert_data/temp/test.0.bert.pt
# [2022-02-25 07:54:33,538 INFO] Loading checkpoint from ../models/mlsum/mlsum_bertsum_model_step_45000.pt
# <summarize.clsprops object at 0x7fddda2a5d50>
# [2022-02-25 07:54:38,837 INFO] Loading test dataset from ../bert_data/temp/test.0.bert.pt, number of examples: 1
# [2022-02-25 07:54:38,856 INFO] * number of parameters: 120957953
# gpu_rank 0
# [2022-02-25 07:54:39,793 INFO] Validation xent: 1.80103 at step 45000
